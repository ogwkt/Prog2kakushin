# %% [markdown]
# <a href="https://colab.research.google.com/github/ogwkt/Prog2kakushin/blob/main/work3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# turtleを用いてピクセルアートを描きます。プログラムを起動すると色と番号が表示され、その色に対応した番号を入力するとその色を使った絵を描きます。

# %%
# !pip3 install ColabTurtlePlus

from ColabTurtlePlus.Turtle import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
while True:
 print('1:黄色')
 print('2:水色')
 print('3:オレンジ')
 print('4:青色')
 print('5:黄緑')
 print('6:紫色')
 print('7:赤色')
 c=input('使う色の番号を入力してください:')
 if c=='1':
  c1='#f6ed03'
  c2='#ffb72a'
  c3='#f6d604'
  break
 elif c=='2':
  c1='#33dff5'
  c2='#33a3f5'
  c3='#33c6f5'
  break
 elif c=='3':
  c1='#ffb900'
  c2='#ff9400'
  c3='#ffac00'
  break
 elif c=='4':
  c1='#0094ff'
  c2='#0094c3'
  c3='#0094e3'
  break
 elif c=='5':
  c1='#acff00'
  c2='#65ff00'
  c3='#91ff00'
  break
 elif c=='6':
  c1='#9700ff'
  c2='#9700d5'
  c3='#9700ed'
  break
 elif c=='7':
  c1='#ff0000'
  c2='#cd0000'
  c3='#e80000'
  break
 else:
  print('存在しません')
  continue
clearscreen()
setup(500,500)
t=Turtle()
t.shape('Turtle')
t.speed(8)
#タンク
t.fillcolor(color=c1)
t.pencolor(color=c1)
t.penup()
t.goto(30,60)
t.pendown()
t.begin_fill()
t.fd(90)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(80)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
#1
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
#タンク影
t.fillcolor(color=c2)
t.pencolor(color=c2)
t.begin_fill()
t.lt(90)
t.fd(90)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(90)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
t.penup()
t.bk(10)
t.pendown()
#タンク光
t.fillcolor(color=c3)
t.pencolor(color=c3)
t.begin_fill()
t.lt(90)
t.fd(70)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(70)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
#タンク光2
t.penup()
t.bk(60)
t.lt(90)
t.fd(40)
t.pendown()
t.begin_fill()
t.fd(40)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.rt(90)
t.fd(10)
t.end_fill()
#装飾の光
t.penup()
t.fillcolor(color='#ff8ade')
t.pencolor(color='#ff8ade')
t.lt(90)
t.fd(10)
t.pendown()
t.begin_fill()
t.fd(30)
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()
#装飾　影1
t.penup()
t.fillcolor(color='#de5ab9')
t.pencolor(color='#de5ab9')
t.bk(70)
t.pendown()
t.begin_fill()
t.fd(10)
t.rt(90)
t.fd(30)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(30)
t.end_fill()
#装飾  影2
t.penup()
t.bk(60)
t.pendown()
t.begin_fill()
t.fd(20)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()
#装飾右
t.penup()
t.fillcolor(color='#ff67d3')
t.pencolor(color='#ff67d3')
t.bk(20)
t.pendown()
t.begin_fill()
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()
#装飾左
t.penup()
t.rt(90)
t.fd(30)
t.pendown()
t.begin_fill()
t.fd(40)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.end_fill()
#銃口影
t.penup()
t.fillcolor(color='#3ed732')
t.pencolor(color='#3ed732')
t.lt(90)
t.fd(40)
t.pendown()
t.begin_fill()
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.end_fill()
#銃口
t.penup()
t.fillcolor(color='#4bde3c')
t.pencolor(color='#4bde3c')
t.bk(30)
t.pendown()
t.begin_fill()
t.fd(20)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(40)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.end_fill()
#銃口光
t.penup()
t.rt(90)
t.fillcolor(color='#53f643')
t.pencolor(color='#53f643')
t.pendown()
t.begin_fill()
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.end_fill()
#銃口下　影
t.penup()
t.fd(10)
t.lt(90)
t.fd(40)
t.fillcolor(color='#3eb732')
t.pencolor(color='#3eb732')
t.pendown()
t.begin_fill()
t.fd(20)
t.rt(90)
t.fd(50)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(50)
t.end_fill()
#銃口下　光
t.penup()
t.fillcolor(color='#4bde3c')
t.pencolor(color='#4bde3c')
t.bk(30)
t.pendown()
t.begin_fill()
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()
#引き金+α
t.penup()
t.fillcolor(color='#282abc')
t.pencolor(color='#282abc')
t.lt(90)
t.fd(20)
t.pendown()
t.begin_fill()
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(20)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()
#持ち手
t.penup()
t.fillcolor(color='#3eb732')
t.pencolor(color='#3eb732')
t.bk(50)
t.lt(90)
t.fd(40)
t.pendown()
t.begin_fill()
t.fd(20)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.end_fill()
#タンク　蓋の影
t.penup()
t.fillcolor(color='#de5ab9')
t.pencolor(color='#de5ab9')
t.fd(110)
t.pendown()
t.begin_fill()
t.fd(20)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(30)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
#タンク　蓋
t.penup()
t.fillcolor(color='#ff67d3')
t.pencolor(color='#ff67d3')
t.bk(30)
t.pendown()
t.begin_fill()
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.rt(90)
t.fd(10)
t.end_fill()
#タンク　蓋の光
t.fillcolor(color='#ff8ade')
t.pencolor(color='#ff8ade')
t.begin_fill()
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(10)
t.lt(90)
t.end_fill()
#カメを画面外へ
t.penup()
t.bk(300)

print('スプラシューター(スプラトゥーン2)')
# Out:
# 1:黄色
# 2:水色
# 3:オレンジ
# 4:青色
# 5:黄緑
# 6:紫色
# 7:赤色
# 使う色の番号を入力してください:8
# 存在しません
# 1:黄色
# 2:水色
# 3:オレンジ
# 4:青色
# 5:黄緑
# 6:紫色
# 7:赤色
# 使う色の番号を入力してください:番号
# 存在しません
# 1:黄色
# 2:水色
# 3:オレンジ
# 4:青色
# 5:黄緑
# 6:紫色
# 7:赤色
# 使う色の番号を入力してください:数字
# 存在しません
# 1:黄色
# 2:水色
# 3:オレンジ
# 4:青色
# 5:黄緑
# 6:紫色
# 7:赤色
# 使う色の番号を入力してください:1
#       <svg width="500" height="500">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...
